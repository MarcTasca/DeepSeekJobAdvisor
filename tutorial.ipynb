# %% [markdown]
# # Tutorial to execute the PoC
# setup:
# - 1. Create a new venv (python3 -m venv venv)
# - 2. activate it (source venv/bin/activate)
# - 3. Install libraries (with cell below)
# - 2. install LM studio and the two models (you do no need to run them):
#     - deepseek-r1-distill-llama-8b
#     - text-embedding-nomic-embed-text-v1.5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Clean jobs_description and conversation, storing them to files_cleaned
# - 1. Install requirements libraries
# - 2. Run the cleaners (they will save files into files_cleaned)

# %%
# clean them up
from cleaning import JobCleaner, ConversationCleaner

job_cleaner = JobCleaner()
job_cleaner.run()

conversation_cleaner = ConversationCleaner()
conversation_cleaner.run();

# %% [markdown]
# ## Embed jobs and profiles:
# - 1. extract relevant jobs (not seen and published) and embed them key by key
# - 2. extract relevant info from candidate_profile and conversation, create a list of potential jobs matching the profile, and embed them key by key
#
# store them to embeddings

# %%
# embed them up
from embedding import JobEmbedder, CandidateEmbedder

job_embedder = JobEmbedder()
job_embedder.run()

candidate_embedder = CandidateEmbedder()
candidate_embedder.run();
# Out:
# Embedding the jobs ...
# 100%|██████████| 627/627 [01:58<00:00,  5.27it/s]
# Saving the job embeddings ...
# Jobs embedded and saved: 627
# Run moodel deepseek-r1-distill-llama-8b to extract candidate profile
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 8
#       5 job_embedder.run()
#       7 candidate_embedder = CandidateEmbedder()
# ----> 8 candidate_embedder.run()
#
# File ~/Desktop/Stema/embedding.py:114, in CandidateEmbedder.run(self)
#     112 def run(self):
#     113     print(f"Run moodel {self.model_summarizer['model']} to extract candidate profile")
# --> 114     self.candidate_profile = self.extract_candidate_profile()
#     115     print(f"Candidate profile extracted: {self.candidate_profile}")
#     117     print("Generate all possible combinations of the candidate profile with model ", self.model_embedder["model"])
#
# ...

# %% [markdown]
# ## Calculate the scores for each job
# - 1. Use cosine similarity to calculate the scores for each key. Confronting potential job matching created from candidate profile and actual jobs
# - 2. update the jobs json, and save it in files_processed

# %%
from embedding import ScoreCalculator

score_calculator = ScoreCalculator()
score_calculator.run();
# Out:
# Loading the job embeddings ...
# 627 <class 'dict'>
# Loading the candidate embeddings ...
# 320 <class 'list'>
# Loading the jobs ...
# 627 <class 'list'>
# Calculating the score for each job ...
# 100%|██████████| 627/627 [00:02<00:00, 217.56it/s]
# Jobs ranked and saved: 627
# [{'job_id': 15606,
#   'job_title': 'FIRE SAFETY SPECIALIST',
#   'apply_type': 'with_email',
#   'platform_url': 'https://stema.io/annuncio/fire-safety-specialist-atm',
#   'status': 'publish',
#   'published_date_time': '2022-08-23 00:00:00',
#   'removed_date_time': None,
#   'updated_date_time': None,
#   'priority_factor': 1,
#   'priority_start_date_time': None,
#   'priority_end_date_time': None,
#   'employer_id': 'a3bd497a-108f-4b1c-a3c0-aba029cc4277',
#   'backgrounds': '{"Ing. Civile/Edile","Ing. Edile-Architettura","Ing. Meccanica"}',
#   'experiences': '{"3-5 Anni","5-10 Anni"}',
#   'provinces': '{Milano}',
#   'roles': '{HSE}',
#   'sectors': '{NULL}',
#   'ral_ranges': '{NULL}',
# ...

# %% [markdown]
# ## Run the streamlit app
# - 1. run the app
# - 2. display all the relevant info
# - 3. run model to create the email

# %%
# !streamlit run frontend.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8502
#   Network URL: http://192.168.1.188:8502
#
#   For better performance, install the Watchdog module:
#
#   $ xcode-select --install
#   $ pip install watchdog
#
# ^C
#   Stopping...
